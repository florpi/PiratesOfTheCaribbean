# %%
#@markdown ### Setup
#@markdown It will restart the kernel after installing the required packages
key = \
'''-----BEGIN OPENSSH PRIVATE KEY-----

-----END OPENSSH PRIVATE KEY-----
'''
# !mkdir -p /root/.ssh
with open(r'/root/.ssh/id_rsa', 'w', encoding='utf8') as fh:
    fh.write(key)
# !chmod 600 /root/.ssh/id_rsa
# !ssh-keyscan github.com >> /root/.ssh/known_hosts 
# !rm -r pirates
#!git clone --single-branch --branch dev git@github.com:Pervasive-Technologies/segmentation_dataset_pipeline.git
# !git clone git@github.com:florpi/PiratesOfTheCaribbean.git pirates
# !cd pirates && python3 setup.py install

import os
import logging
def restart_runtime():
    logging.warning('Restarting runtime... Please continue from next cell.')
    os.kill(os.getpid(), 9)
restart_runtime()
# Out:
# # github.com:22 SSH-2.0-babeld-2e9d163d
# # github.com:22 SSH-2.0-babeld-2e9d163d
# # github.com:22 SSH-2.0-babeld-2e9d163d
# rm: cannot remove 'pirates': No such file or directory
# Cloning into 'pirates'...
# Warning: Permanently added the RSA host key for IP address '140.82.118.3' to the list of known hosts.
# remote: Enumerating objects: 188, done.
# remote: Counting objects: 100% (188/188), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 188 (delta 106), reused 153 (delta 72), pack-reused 0
# Receiving objects: 100% (188/188), 3.88 MiB | 5.99 MiB/s, done.
# Resolving deltas: 100% (106/106), done.
# running install
# running bdist_egg
# running egg_info
# creating pirates.egg-info
# writing pirates.egg-info/PKG-INFO
# writing dependency_links to pirates.egg-info/dependency_links.txt
# writing requirements to pirates.egg-info/requires.txt
# writing top-level names to pirates.egg-info/top_level.txt
# writing manifest file 'pirates.egg-info/SOURCES.txt'
# writing manifest file 'pirates.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/pirates
# copying pirates/__init__.py -> build/lib/pirates
# creating build/lib/pirates/visualization
# copying pirates/visualization/visualize.py -> build/lib/pirates/visualization
# copying pirates/visualization/__init__.py -> build/lib/pirates/visualization
# creating build/lib/pirates/models
# copying pirates/models/inputs_model.py -> build/lib/pirates/models
# copying pirates/models/predict_model.py -> build/lib/pirates/models
# copying pirates/models/train_model.py -> build/lib/pirates/models
# copying pirates/models/__init__.py -> build/lib/pirates/models
# creating build/lib/pirates/data
# copying pirates/data/make_dataset.py -> build/lib/pirates/data
# copying pirates/data/__init__.py -> build/lib/pirates/data
# creating build/lib/pirates/features
# copying pirates/features/build_features.py -> build/lib/pirates/features
# copying pirates/features/__init__.py -> build/lib/pirates/features
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/pirates
# creating build/bdist.linux-x86_64/egg/pirates/visualization
# copying build/lib/pirates/visualization/visualize.py -> build/bdist.linux-x86_64/egg/pirates/visualization
# copying build/lib/pirates/visualization/__init__.py -> build/bdist.linux-x86_64/egg/pirates/visualization
# creating build/bdist.linux-x86_64/egg/pirates/models
# copying build/lib/pirates/models/inputs_model.py -> build/bdist.linux-x86_64/egg/pirates/models
# copying build/lib/pirates/models/predict_model.py -> build/bdist.linux-x86_64/egg/pirates/models
# copying build/lib/pirates/models/train_model.py -> build/bdist.linux-x86_64/egg/pirates/models
# copying build/lib/pirates/models/__init__.py -> build/bdist.linux-x86_64/egg/pirates/models
# creating build/bdist.linux-x86_64/egg/pirates/data
# copying build/lib/pirates/data/make_dataset.py -> build/bdist.linux-x86_64/egg/pirates/data
# copying build/lib/pirates/data/__init__.py -> build/bdist.linux-x86_64/egg/pirates/data
# creating build/bdist.linux-x86_64/egg/pirates/features
# copying build/lib/pirates/features/build_features.py -> build/bdist.linux-x86_64/egg/pirates/features
# copying build/lib/pirates/features/__init__.py -> build/bdist.linux-x86_64/egg/pirates/features
# copying build/lib/pirates/__init__.py -> build/bdist.linux-x86_64/egg/pirates
# byte-compiling build/bdist.linux-x86_64/egg/pirates/visualization/visualize.py to visualize.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pirates/visualization/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pirates/models/inputs_model.py to inputs_model.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pirates/models/predict_model.py to predict_model.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pirates/models/train_model.py to train_model.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pirates/models/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pirates/data/make_dataset.py to make_dataset.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pirates/data/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pirates/features/build_features.py to build_features.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pirates/features/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pirates/__init__.py to __init__.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying pirates.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pirates.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pirates.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pirates.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pirates.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# pirates.data.__pycache__.make_dataset.cpython-36: module references __file__
# creating dist
# creating 'dist/pirates-0.1.0-py3.6.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing pirates-0.1.0-py3.6.egg
# creating /usr/local/lib/python3.6/dist-packages/pirates-0.1.0-py3.6.egg
# Extracting pirates-0.1.0-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding pirates 0.1.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/pirates-0.1.0-py3.6.egg
# Processing dependencies for pirates==0.1.0
# Searching for comet_ml
# Reading https://pypi.org/simple/comet_ml/
# Downloading https://files.pythonhosted.org/packages/a2/c0/d5899f974be6e2a78c1f5d750fa71f73b3cbcd5df58ff7dfce8b7c0fc106/comet_ml-2.0.17-py3-none-any.whl#sha256=3033087a02e10642b0850ffdc57390ed386e818d728bcaa8348d335030f5f559
# Best match: comet-ml 2.0.17
# Processing comet_ml-2.0.17-py3-none-any.whl
# Installing comet_ml-2.0.17-py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/comet_ml-2.0.17-py3.6.egg/EGG-INFO/requires.txt
# Adding comet-ml 2.0.17 to easy-install.pth file
# Installing comet script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/comet_ml-2.0.17-py3.6.egg
# Searching for opencv-python>=4.1.1
# Reading https://pypi.org/simple/opencv-python/
# Downloading https://files.pythonhosted.org/packages/5e/7e/bd5425f4dacb73367fddc71388a47c1ea570839197c2bcad86478e565186/opencv_python-4.1.1.26-cp36-cp36m-manylinux1_x86_64.whl#sha256=67d994c6b2b14cb9239e85dc7dfa6c08ef7cf6eb4def80c0af6141dfacc8cbb9
# Best match: opencv-python 4.1.1.26
# Processing opencv_python-4.1.1.26-cp36-cp36m-manylinux1_x86_64.whl
# Installing opencv_python-4.1.1.26-cp36-cp36m-manylinux1_x86_64.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/opencv_python-4.1.1.26-py3.6-linux-x86_64.egg/EGG-INFO/requires.txt
# Adding opencv-python 4.1.1.26 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/opencv_python-4.1.1.26-py3.6-linux-x86_64.egg
# Searching for rasterio>=1.1.0
# Reading https://pypi.org/simple/rasterio/
# Downloading https://files.pythonhosted.org/packages/94/da/a06e29e22dd464e618ae0fe580f444b0782ccf75fe3a784249cb59534f32/rasterio-1.1.1-cp36-cp36m-manylinux1_x86_64.whl#sha256=c5e4ac8f1d645be238cf317d417bd1f371a8a274029e2e1212b2a21753e82a9e
# Best match: rasterio 1.1.1
# Processing rasterio-1.1.1-cp36-cp36m-manylinux1_x86_64.whl
# Installing rasterio-1.1.1-cp36-cp36m-manylinux1_x86_64.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/rasterio-1.1.1-py3.6-linux-x86_64.egg/EGG-INFO/requires.txt
# Adding rasterio 1.1.1 to easy-install.pth file
# Installing rio script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/rasterio-1.1.1-py3.6-linux-x86_64.egg
# Searching for geopandas>=0.6.1
# Reading https://pypi.org/simple/geopandas/
# Downloading https://files.pythonhosted.org/packages/59/39/de0263d511d4fc35a640cf00d02e497eb60698315a22936bedbdd904d7f7/geopandas-0.6.1-py2.py3-none-any.whl#sha256=205fc407deb3a31742f90e6e0e478fdb5c3352604223324e5236d6e2037aa2b5
# Best match: geopandas 0.6.1
# Processing geopandas-0.6.1-py2.py3-none-any.whl
# Installing geopandas-0.6.1-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/geopandas-0.6.1-py3.6.egg/EGG-INFO/requires.txt
# Adding geopandas 0.6.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/geopandas-0.6.1-py3.6.egg
# Searching for python-dotenv>=0.5.1
# Reading https://pypi.org/simple/python-dotenv/
# Downloading https://files.pythonhosted.org/packages/57/c8/5b14d5cffe7bb06bedf9d66c4562bf90330d3d35e7f0266928c370d9dd6d/python_dotenv-0.10.3-py2.py3-none-any.whl#sha256=debd928b49dbc2bf68040566f55cdb3252458036464806f4094487244e2a4093
# Best match: python-dotenv 0.10.3
# Processing python_dotenv-0.10.3-py2.py3-none-any.whl
# Installing python_dotenv-0.10.3-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/python_dotenv-0.10.3-py3.6.egg/EGG-INFO/requires.txt
# Adding python-dotenv 0.10.3 to easy-install.pth file
# Installing dotenv script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/python_dotenv-0.10.3-py3.6.egg
# Searching for flake8
# Reading https://pypi.org/simple/flake8/
# Downloading https://files.pythonhosted.org/packages/f8/1f/7ea40d1e4146ea55dbab41cda1376db092a75794914169aabd7e8d7a7def/flake8-3.7.9-py2.py3-none-any.whl#sha256=49356e766643ad15072a789a20915d3c91dc89fd313ccd71802303fd67e4deca
# Best match: flake8 3.7.9
# Processing flake8-3.7.9-py2.py3-none-any.whl
# Installing flake8-3.7.9-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/flake8-3.7.9-py3.6.egg/EGG-INFO/requires.txt
# Adding flake8 3.7.9 to easy-install.pth file
# Installing flake8 script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/flake8-3.7.9-py3.6.egg
# Searching for awscli
# Reading https://pypi.org/simple/awscli/
# Downloading https://files.pythonhosted.org/packages/e2/6d/392fbb522445a6422cf93ddee0a066924fabcb11089ea8105dd94d0a2227/awscli-1.16.283-py2.py3-none-any.whl#sha256=a3b118aec8387722649596ddd4c5970e35f9529af7170bbfa8f835872b97b4a2
# Best match: awscli 1.16.283
# Processing awscli-1.16.283-py2.py3-none-any.whl
# Installing awscli-1.16.283-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/awscli-1.16.283-py3.6.egg/EGG-INFO/requires.txt
# Adding awscli 1.16.283 to easy-install.pth file
# Installing aws.cmd script to /usr/local/bin
# Installing aws script to /usr/local/bin
# Installing aws_zsh_completer.sh script to /usr/local/bin
# Installing aws_completer script to /usr/local/bin
# Installing aws_bash_completer script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/awscli-1.16.283-py3.6.egg
# Searching for wurlitzer>=1.0.2
# Reading https://pypi.org/simple/wurlitzer/
# Downloading https://files.pythonhosted.org/packages/24/5e/f3bd8443bfdf96d2f5d10097d301076a9eb55637b7864e52d2d1a4d8c72a/wurlitzer-2.0.0-py2.py3-none-any.whl#sha256=eec7e3c779ddbf32d7e962ccc457580d1696f887e74ede45ebefaf6d12e7bf8f
# Best match: wurlitzer 2.0.0
# Processing wurlitzer-2.0.0-py2.py3-none-any.whl
# Installing wurlitzer-2.0.0-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding wurlitzer 2.0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/wurlitzer-2.0.0-py3.6.egg
# Searching for websocket-client>=0.55.0
# Reading https://pypi.org/simple/websocket-client/
# Downloading https://files.pythonhosted.org/packages/29/19/44753eab1fdb50770ac69605527e8859468f3c0fd7dc5a76dd9c4dbd7906/websocket_client-0.56.0-py2.py3-none-any.whl#sha256=1151d5fb3a62dc129164292e1227655e4bbc5dd5340a5165dfae61128ec50aa9
# Best match: websocket-client 0.56.0
# Processing websocket_client-0.56.0-py2.py3-none-any.whl
# Installing websocket_client-0.56.0-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/websocket_client-0.56.0-py3.6.egg/EGG-INFO/requires.txt
# Adding websocket-client 0.56.0 to easy-install.pth file
# Installing wsdump.py script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/websocket_client-0.56.0-py3.6.egg
# Searching for netifaces>=0.10.7
# Reading https://pypi.org/simple/netifaces/
# Downloading https://files.pythonhosted.org/packages/0c/9b/c4c7eb09189548d45939a3d3a6b3d53979c67d124459b27a094c365c347f/netifaces-0.10.9-cp36-cp36m-manylinux1_x86_64.whl#sha256=30ed89ab8aff715caf9a9d827aa69cd02ad9f6b1896fd3fb4beb998466ed9a3c
# Best match: netifaces 0.10.9
# Processing netifaces-0.10.9-cp36-cp36m-manylinux1_x86_64.whl
# Installing netifaces-0.10.9-cp36-cp36m-manylinux1_x86_64.whl to /usr/local/lib/python3.6/dist-packages
# Adding netifaces 0.10.9 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/netifaces-0.10.9-py3.6-linux-x86_64.egg
# Searching for everett[ini]>=1.0.1
# Reading https://pypi.org/simple/everett/
# Downloading https://files.pythonhosted.org/packages/12/34/de70a3d913411e40ce84966f085b5da0c6df741e28c86721114dd290aaa0/everett-1.0.2-py2.py3-none-any.whl#sha256=8a5ee8cdde0ed6b3bbb63249e0e0703d4ad91921107ff198e0868ffce5f7b6bc
# Best match: everett 1.0.2
# Processing everett-1.0.2-py2.py3-none-any.whl
# Installing everett-1.0.2-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/everett-1.0.2-py3.6.egg/EGG-INFO/requires.txt
# Adding everett 1.0.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/everett-1.0.2-py3.6.egg
# Searching for comet-git-pure>=0.19.11
# Reading https://pypi.org/simple/comet-git-pure/
# Downloading https://files.pythonhosted.org/packages/5a/ed/70aa248684c66ba559c690bc3a77227b1c9a04e641893865ea833c4329dd/comet_git_pure-0.19.13-py3-none-any.whl#sha256=222163113a4236b8e8b6248614cd034330c9f412f49eae44c426e2454cf44b04
# Best match: comet-git-pure 0.19.13
# Processing comet_git_pure-0.19.13-py3-none-any.whl
# Installing comet_git_pure-0.19.13-py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/comet_git_pure-0.19.13-py3.6.egg/EGG-INFO/requires.txt
# Adding comet-git-pure 0.19.13 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/comet_git_pure-0.19.13-py3.6.egg
# Searching for snuggs>=1.4.1
# Reading https://pypi.org/simple/snuggs/
# Downloading https://files.pythonhosted.org/packages/cc/0e/d27d6e806d6c0d1a2cfdc5d1f088e42339a0a54a09c3343f7f81ec8947ea/snuggs-1.4.7-py3-none-any.whl#sha256=988dde5d4db88e9d71c99457404773dabcc7a1c45971bfbe81900999942d9f07
# Best match: snuggs 1.4.7
# Processing snuggs-1.4.7-py3-none-any.whl
# Installing snuggs-1.4.7-py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/snuggs-1.4.7-py3.6.egg/EGG-INFO/requires.txt
# Adding snuggs 1.4.7 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/snuggs-1.4.7-py3.6.egg
# Searching for cligj>=0.5
# Reading https://pypi.org/simple/cligj/
# Downloading https://files.pythonhosted.org/packages/e4/be/30a58b4b0733850280d01f8bd132591b4668ed5c7046761098d665ac2174/cligj-0.5.0-py3-none-any.whl#sha256=20f24ce9abfde3f758aec3399e6811b936b6772f360846c662c19bf5537b4f14
# Best match: cligj 0.5.0
# Processing cligj-0.5.0-py3-none-any.whl
# Installing cligj-0.5.0-py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/cligj-0.5.0-py3.6.egg/EGG-INFO/requires.txt
# Adding cligj 0.5.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/cligj-0.5.0-py3.6.egg
# Searching for click-plugins
# Reading https://pypi.org/simple/click-plugins/
# Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl#sha256=5d262006d3222f5057fd81e1623d4443e41dcda5dc815c06b442aa3c02889fc8
# Best match: click-plugins 1.1.1
# Processing click_plugins-1.1.1-py2.py3-none-any.whl
# Installing click_plugins-1.1.1-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/click_plugins-1.1.1-py3.6.egg/EGG-INFO/requires.txt
# Adding click-plugins 1.1.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/click_plugins-1.1.1-py3.6.egg
# Searching for affine
# Reading https://pypi.org/simple/affine/
# Downloading https://files.pythonhosted.org/packages/ac/a6/1a39a1ede71210e3ddaf623982b06ecfc5c5c03741ae659073159184cd3e/affine-2.3.0-py2.py3-none-any.whl#sha256=34b05b070d954c382e56f02c207a372d8a32621a87653cc30cdd31cd7f65799f
# Best match: affine 2.3.0
# Processing affine-2.3.0-py2.py3-none-any.whl
# Installing affine-2.3.0-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/affine-2.3.0-py3.6.egg/EGG-INFO/requires.txt
# Adding affine 2.3.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/affine-2.3.0-py3.6.egg
# Searching for pyproj
# Reading https://pypi.org/simple/pyproj/
# Downloading https://files.pythonhosted.org/packages/e1/45/74cf159d802b1616447bc451fe07fb0d7eadb3b62ff77636427d40e3b61e/pyproj-2.4.1-cp36-cp36m-manylinux1_x86_64.whl#sha256=1ea692abc31199d3b0c614d0f8d0b8e8cf0ac9d104df6cbd1159ed4f6c12f318
# Best match: pyproj 2.4.1
# Processing pyproj-2.4.1-cp36-cp36m-manylinux1_x86_64.whl
# Installing pyproj-2.4.1-cp36-cp36m-manylinux1_x86_64.whl to /usr/local/lib/python3.6/dist-packages
# Adding pyproj 2.4.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/pyproj-2.4.1-py3.6-linux-x86_64.egg
# Searching for fiona
# Reading https://pypi.org/simple/fiona/
# Downloading https://files.pythonhosted.org/packages/a6/8f/abad0244b2872fca20e49b149c6680a89171c3af9735e9dfa7eb33cc187a/Fiona-1.8.11-cp36-cp36m-manylinux1_x86_64.whl#sha256=1c9ff0f799d41570fd9e2d40bbad174bab8787e9149fed04364488349109b944
# Best match: Fiona 1.8.11
# Processing Fiona-1.8.11-cp36-cp36m-manylinux1_x86_64.whl
# Installing Fiona-1.8.11-cp36-cp36m-manylinux1_x86_64.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/Fiona-1.8.11-py3.6-linux-x86_64.egg/EGG-INFO/requires.txt
# Adding Fiona 1.8.11 to easy-install.pth file
# Installing fio script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/Fiona-1.8.11-py3.6-linux-x86_64.egg
# Searching for pyflakes<2.2.0,>=2.1.0
# Reading https://pypi.org/simple/pyflakes/
# Downloading https://files.pythonhosted.org/packages/84/f2/ed0ffb887f8138a8fe5a621b8c0bb9598bfb3989e029f6c6a85ee66628ee/pyflakes-2.1.1-py2.py3-none-any.whl#sha256=17dbeb2e3f4d772725c777fabc446d5634d1038f234e77343108ce445ea69ce0
# Best match: pyflakes 2.1.1
# Processing pyflakes-2.1.1-py2.py3-none-any.whl
# Installing pyflakes-2.1.1-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding pyflakes 2.1.1 to easy-install.pth file
# Installing pyflakes script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/pyflakes-2.1.1-py3.6.egg
# Searching for pycodestyle<2.6.0,>=2.5.0
# Reading https://pypi.org/simple/pycodestyle/
# Downloading https://files.pythonhosted.org/packages/0e/0c/04a353e104d2f324f8ee5f4b32012618c1c86dd79e52a433b64fceed511b/pycodestyle-2.5.0-py2.py3-none-any.whl#sha256=95a2219d12372f05704562a14ec30bc76b05a5b297b21a5dfe3f6fac3491ae56
# Best match: pycodestyle 2.5.0
# Processing pycodestyle-2.5.0-py2.py3-none-any.whl
# Installing pycodestyle-2.5.0-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding pycodestyle 2.5.0 to easy-install.pth file
# Installing pycodestyle script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/pycodestyle-2.5.0-py3.6.egg
# Searching for mccabe<0.7.0,>=0.6.0
# Reading https://pypi.org/simple/mccabe/
# Downloading https://files.pythonhosted.org/packages/87/89/479dc97e18549e21354893e4ee4ef36db1d237534982482c3681ee6e7b57/mccabe-0.6.1-py2.py3-none-any.whl#sha256=ab8a6258860da4b6677da4bd2fe5dc2c659cff31b3ee4f7f5d64e79735b80d42
# Best match: mccabe 0.6.1
# Processing mccabe-0.6.1-py2.py3-none-any.whl
# Installing mccabe-0.6.1-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding mccabe 0.6.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/mccabe-0.6.1-py3.6.egg
# Searching for rsa<=3.5.0,>=3.1.2
# Reading https://pypi.org/simple/rsa/
# Downloading https://files.pythonhosted.org/packages/e1/ae/baedc9cb175552e95f3395c43055a6a5e125ae4d48a1d7a924baca83e92e/rsa-3.4.2-py2.py3-none-any.whl#sha256=43f682fea81c452c98d09fc316aae12de6d30c4b5c84226642cf8f8fd1c93abd
# Best match: rsa 3.4.2
# Processing rsa-3.4.2-py2.py3-none-any.whl
# Installing rsa-3.4.2-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/rsa-3.4.2-py3.6.egg/EGG-INFO/requires.txt
# Adding rsa 3.4.2 to easy-install.pth file
# Installing pyrsa-decrypt script to /usr/local/bin
# Installing pyrsa-decrypt-bigfile script to /usr/local/bin
# Installing pyrsa-encrypt script to /usr/local/bin
# Installing pyrsa-encrypt-bigfile script to /usr/local/bin
# Installing pyrsa-keygen script to /usr/local/bin
# Installing pyrsa-priv2pub script to /usr/local/bin
# Installing pyrsa-sign script to /usr/local/bin
# Installing pyrsa-verify script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/rsa-3.4.2-py3.6.egg
# Searching for colorama<0.4.2,>=0.2.5
# Reading https://pypi.org/simple/colorama/
# Downloading https://files.pythonhosted.org/packages/4f/a6/728666f39bfff1719fc94c481890b2106837da9318031f71a8424b662e12/colorama-0.4.1-py2.py3-none-any.whl#sha256=f8ac84de7840f5b9c4e3347b3c1eaa50f7e49c2b07596221daec5edaabbd7c48
# Best match: colorama 0.4.1
# Processing colorama-0.4.1-py2.py3-none-any.whl
# Installing colorama-0.4.1-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding colorama 0.4.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/colorama-0.4.1-py3.6.egg
# Searching for botocore==1.13.19
# Reading https://pypi.org/simple/botocore/
# Downloading https://files.pythonhosted.org/packages/18/e5/0f29669244ffacc15c4cec9e10d75c26e7d300e1786e79514e62373e648c/botocore-1.13.19-py2.py3-none-any.whl#sha256=93613735b76d5fde3bee0d228566d37483c6ea09adcd7615a66f7443ac0f08f2
# Best match: botocore 1.13.19
# Processing botocore-1.13.19-py2.py3-none-any.whl
# Installing botocore-1.13.19-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/botocore-1.13.19-py3.6.egg/EGG-INFO/requires.txt
# Adding botocore 1.13.19 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/botocore-1.13.19-py3.6.egg
# Searching for configobj
# Reading https://pypi.org/simple/configobj/
# Downloading https://files.pythonhosted.org/packages/64/61/079eb60459c44929e684fa7d9e2fdca403f67d64dd9dbac27296be2e0fab/configobj-5.0.6.tar.gz#sha256=a2f5650770e1c87fb335af19a9b7eb73fc05ccf22144eb68db7d00cd2bcb0902
# Best match: configobj 5.0.6
# Processing configobj-5.0.6.tar.gz
# Writing /tmp/easy_install-ng0k8h5v/configobj-5.0.6/setup.cfg
# Running configobj-5.0.6/setup.py -q bdist_egg --dist-dir /tmp/easy_install-ng0k8h5v/configobj-5.0.6/egg-dist-tmp-y_olwpp9
# zip_safe flag not set; analyzing archive contents...
# Moving configobj-5.0.6-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding configobj 5.0.6 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/configobj-5.0.6-py3.6.egg
# Searching for munch
# Reading https://pypi.org/simple/munch/
# Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl#sha256=6f44af89a2ce4ed04ff8de41f70b226b984db10a91dcc7b9ac2efc1c77022fdd
# Best match: munch 2.5.0
# Processing munch-2.5.0-py2.py3-none-any.whl
# Installing munch-2.5.0-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# writing requirements to /usr/local/lib/python3.6/dist-packages/munch-2.5.0-py3.6.egg/EGG-INFO/requires.txt
# Adding munch 2.5.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/munch-2.5.0-py3.6.egg
# Searching for tensorflow-hub==0.7.0
# Best match: tensorflow-hub 0.7.0
# Adding tensorflow-hub 0.7.0 to easy-install.pth file
# Installing make_image_classifier script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tensorflow==1.15.0
# Best match: tensorflow 1.15.0
# Adding tensorflow 1.15.0 to easy-install.pth file
# Installing estimator_ckpt_converter script to /usr/local/bin
# Installing freeze_graph script to /usr/local/bin
# Installing saved_model_cli script to /usr/local/bin
# Installing tensorboard script to /usr/local/bin
# Installing tf_upgrade_v2 script to /usr/local/bin
# Installing tflite_convert script to /usr/local/bin
# Installing toco script to /usr/local/bin
# Installing toco_from_protos script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Keras==2.2.5
# Best match: Keras 2.2.5
# Adding Keras 2.2.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Shapely==1.6.4.post2
# Best match: Shapely 1.6.4.post2
# Adding Shapely 1.6.4.post2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for seaborn==0.9.0
# Best match: seaborn 0.9.0
# Adding seaborn 0.9.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pandas==0.25.3
# Best match: pandas 0.25.3
# Adding pandas 0.25.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for numpy==1.17.4
# Best match: numpy 1.17.4
# Adding numpy 1.17.4 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.6 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for coverage==3.7.1
# Best match: coverage 3.7.1
# Adding coverage 3.7.1 to easy-install.pth file
# Installing coverage script to /usr/local/bin
# Installing coverage-3.6 script to /usr/local/bin
# Installing coverage3 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Sphinx==1.8.5
# Best match: Sphinx 1.8.5
# Adding Sphinx 1.8.5 to easy-install.pth file
# Installing sphinx-apidoc script to /usr/local/bin
# Installing sphinx-autogen script to /usr/local/bin
# Installing sphinx-build script to /usr/local/bin
# Installing sphinx-quickstart script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Click==7.0
# Best match: Click 7.0
# Adding Click 7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for six==1.12.0
# Best match: six 1.12.0
# Adding six 1.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for requests==2.21.0
# Best match: requests 2.21.0
# Adding requests 2.21.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for nvidia-ml-py3==7.352.0
# Best match: nvidia-ml-py3 7.352.0
# Adding nvidia-ml-py3 7.352.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for jsonschema==2.6.0
# Best match: jsonschema 2.6.0
# Adding jsonschema 2.6.0 to easy-install.pth file
# Installing jsonschema script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for protobuf==3.10.0
# Best match: protobuf 3.10.0
# Adding protobuf 3.10.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for gast==0.2.2
# Best match: gast 0.2.2
# Adding gast 0.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Keras-Applications==1.0.8
# Best match: Keras-Applications 1.0.8
# Adding Keras-Applications 1.0.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tensorflow-estimator==1.15.1
# Best match: tensorflow-estimator 1.15.1
# Adding tensorflow-estimator 1.15.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tensorboard==1.15.0
# Best match: tensorboard 1.15.0
# Adding tensorboard 1.15.0 to easy-install.pth file
# Installing tensorboard script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for termcolor==1.1.0
# Best match: termcolor 1.1.0
# Adding termcolor 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Keras-Preprocessing==1.1.0
# Best match: Keras-Preprocessing 1.1.0
# Adding Keras-Preprocessing 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for wheel==0.33.6
# Best match: wheel 0.33.6
# Adding wheel 0.33.6 to easy-install.pth file
# Installing wheel script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for grpcio==1.15.0
# Best match: grpcio 1.15.0
# Adding grpcio 1.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for wrapt==1.11.2
# Best match: wrapt 1.11.2
# Adding wrapt 1.11.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for opt-einsum==3.1.0
# Best match: opt-einsum 3.1.0
# Adding opt-einsum 3.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for google-pasta==0.1.8
# Best match: google-pasta 0.1.8
# Adding google-pasta 0.1.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for absl-py==0.8.1
# Best match: absl-py 0.8.1
# Adding absl-py 0.8.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for astor==0.8.0
# Best match: astor 0.8.0
# Adding astor 0.8.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for h5py==2.8.0
# Best match: h5py 2.8.0
# Adding h5py 2.8.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for scipy==1.3.2
# Best match: scipy 1.3.2
# Adding scipy 1.3.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for PyYAML==3.13
# Best match: PyYAML 3.13
# Adding PyYAML 3.13 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for attrs==19.3.0
# Best match: attrs 19.3.0
# Adding attrs 19.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for matplotlib==3.1.1
# Best match: matplotlib 3.1.1
# Adding matplotlib 3.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for python-dateutil==2.6.1
# Best match: python-dateutil 2.6.1
# Adding python-dateutil 2.6.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pytz==2018.9
# Best match: pytz 2018.9
# Adding pytz 2018.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for entrypoints==0.3
# Best match: entrypoints 0.3
# Adding entrypoints 0.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for s3transfer==0.2.1
# Best match: s3transfer 0.2.1
# Adding s3transfer 0.2.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for docutils==0.15.2
# Best match: docutils 0.15.2
# Adding docutils 0.15.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for setuptools==41.4.0
# Best match: setuptools 41.4.0
# Adding setuptools 41.4.0 to easy-install.pth file
# Installing easy_install script to /usr/local/bin
# Installing easy_install-3.6 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for imagesize==1.1.0
# Best match: imagesize 1.1.0
# Adding imagesize 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for snowballstemmer==2.0.0
# Best match: snowballstemmer 2.0.0
# Adding snowballstemmer 2.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for sphinxcontrib-websupport==1.1.2
# Best match: sphinxcontrib-websupport 1.1.2
# Adding sphinxcontrib-websupport 1.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Pygments==2.1.3
# Best match: Pygments 2.1.3
# Adding Pygments 2.1.3 to easy-install.pth file
# Installing pygmentize script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for packaging==19.2
# Best match: packaging 19.2
# Adding packaging 19.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for alabaster==0.7.12
# Best match: alabaster 0.7.12
# Adding alabaster 0.7.12 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Jinja2==2.10.3
# Best match: Jinja2 2.10.3
# Adding Jinja2 2.10.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Babel==2.7.0
# Best match: Babel 2.7.0
# Adding Babel 2.7.0 to easy-install.pth file
# Installing pybabel script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for urllib3==1.24.3
# Best match: urllib3 1.24.3
# Adding urllib3 1.24.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for chardet==3.0.4
# Best match: chardet 3.0.4
# Adding chardet 3.0.4 to easy-install.pth file
# Installing chardetect script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for certifi==2019.9.11
# Best match: certifi 2019.9.11
# Adding certifi 2019.9.11 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for idna==2.8
# Best match: idna 2.8
# Adding idna 2.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Markdown==3.1.1
# Best match: Markdown 3.1.1
# Adding Markdown 3.1.1 to easy-install.pth file
# Installing markdown_py script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Werkzeug==0.16.0
# Best match: Werkzeug 0.16.0
# Adding Werkzeug 0.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pyparsing==2.4.5
# Best match: pyparsing 2.4.5
# Adding pyparsing 2.4.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for kiwisolver==1.1.0
# Best match: kiwisolver 1.1.0
# Adding kiwisolver 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for cycler==0.10.0
# Best match: cycler 0.10.0
# Adding cycler 0.10.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pyasn1==0.4.7
# Best match: pyasn1 0.4.7
# Adding pyasn1 0.4.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for jmespath==0.9.4
# Best match: jmespath 0.9.4
# Adding jmespath 0.9.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for MarkupSafe==1.1.1
# Best match: MarkupSafe 1.1.1
# Adding MarkupSafe 1.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Finished processing dependencies for pirates==0.1.0
# WARNING:root:Restarting runtime... Please continue from next cell.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
from pirates.models import train_model, inputs_model
import keras
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %%
IMAGE_SHAPE = (224, 224)
dataframes_pattern = "drive/My Drive/pirates/data/processed/train/*.pkl"
imgs_pattern =  "drive/My Drive/pirates/data/raw/**/**/*.tif"
train_gen = inputs_model.get_dataset_generator(imgs_pattern,
                                               dataframes_pattern,
                                               10,
                                               IMAGE_SHAPE,                                               
                                               augment=True,
                                               return_ids=False,
                                               return_labels=True)
# Out:
# INFO:root:Mapping zones to images: {'gros_islet': 'drive/My Drive/pirates/data/raw/st_lucia/gros_islet/gros_islet_ortho-cog.tif', 'castries': 'drive/My Drive/pirates/data/raw/st_lucia/castries/castries_ortho-cog.tif', 'dennery': 'drive/My Drive/pirates/data/raw/st_lucia/dennery/dennery_ortho-cog.tif', 'borde_rural': 'drive/My Drive/pirates/data/raw/colombia/borde_rural/borde_rural_ortho-cog.tif', 'borde_soacha': 'drive/My Drive/pirates/data/raw/colombia/borde_soacha/borde_soacha_ortho-cog.tif', 'mixco_3': 'drive/My Drive/pirates/data/raw/guatemala/mixco_3/mixco_3_ortho-cog.tif', 'mixco_1_and_ebenezer': 'drive/My Drive/pirates/data/raw/guatemala/mixco_1_and_ebenezer/mixco_1_and_ebenezer_ortho-cog.tif'}

# %%
dataframes_pattern = "drive/My Drive/pirates/data/processed/validate/*.pkl"
imgs_pattern =  "drive/My Drive/pirates/data/raw/**/**/*.tif"
val_gen = inputs_model.get_dataset_generator(imgs_pattern,
                                             dataframes_pattern,
                                             1,
                                             IMAGE_SHAPE,                                               
                                             augment=False,
                                             return_ids=False,
                                             return_labels=True)
# Out:
# INFO:root:Mapping zones to images: {'gros_islet': 'drive/My Drive/pirates/data/raw/st_lucia/gros_islet/gros_islet_ortho-cog.tif', 'castries': 'drive/My Drive/pirates/data/raw/st_lucia/castries/castries_ortho-cog.tif', 'dennery': 'drive/My Drive/pirates/data/raw/st_lucia/dennery/dennery_ortho-cog.tif', 'borde_rural': 'drive/My Drive/pirates/data/raw/colombia/borde_rural/borde_rural_ortho-cog.tif', 'borde_soacha': 'drive/My Drive/pirates/data/raw/colombia/borde_soacha/borde_soacha_ortho-cog.tif', 'mixco_3': 'drive/My Drive/pirates/data/raw/guatemala/mixco_3/mixco_3_ortho-cog.tif', 'mixco_1_and_ebenezer': 'drive/My Drive/pirates/data/raw/guatemala/mixco_1_and_ebenezer/mixco_1_and_ebenezer_ortho-cog.tif'}

# %%
dataframes_pattern = "drive/My Drive/pirates/data/processed/test/*.pkl"
imgs_pattern =  "drive/My Drive/pirates/data/raw/**/**/*.tif"
test_gen = inputs_model.get_dataset_generator(imgs_pattern,
                                              dataframes_pattern,
                                              1,
                                              IMAGE_SHAPE,                                               
                                              augment=False,
                                              return_ids=True,
                                              return_labels=False)

# %%
train_model.transfer_train(train_gen, val_gen, test_gen)
# Out:
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Data:
# COMET INFO:     url: https://www.comet.ml/florpi/piratesofthecaribbean/5043b3707cfa4efbbedb7686e67e7997
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     sys.cpu.percent.01       : (14.1, 14.1)
# COMET INFO:     sys.cpu.percent.02       : (13.5, 13.5)
# COMET INFO:     sys.cpu.percent.avg      : (13.8, 13.8)
# COMET INFO:     sys.gpu.0.free_memory    : (11996954624.0, 11996954624.0)
# COMET INFO:     sys.gpu.0.gpu_utilization: (0.0, 0.0)
# COMET INFO:     sys.gpu.0.total_memory   : (11996954624.0, 11996954624.0)
# COMET INFO:     sys.gpu.0.used_memory    : (0.0, 0.0)
# COMET INFO:     sys.ram.total            : (13655228416.0, 13655228416.0)
# COMET INFO:     sys.ram.used             : (875700224.0, 875700224.0)
# COMET INFO:   Other [count]:
# COMET INFO:     trainable_params: 4275001
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/florpi/piratesofthecaribbean/f2a861576d8a4251b98fe37135b21c38
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_1 (KerasLayer)   (None, 1056)              4269716
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5285
# =================================================================
# Total params: 4,275,001
# Trainable params: 5,285
# Non-trainable params: 4,269,716
# _________________________________________________________________
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-a7e9fb0fafeb> in <module>()
# ----> 1 train_model.transfer_train(train_gen, val_gen)
#
# /usr/local/lib/python3.6/dist-packages/pirates-0.1.0-py3.6.egg/pirates/models/train_model.py in transfer_train(train_generator, validation_generator, train_all, BATCH_SIZE, N_EPOCHS)
#      77     history = model.fit_generator(train_generator, epochs=N_EPOCHS,
#      78                                   validation_data=validation_generator,
# ---> 79                                   callbacks = [batch_stats_callback])
#      80
#      81     probabilities = []
#
# /usr/local/lib/python3.6/dist-packages/comet_ml-2.0.17-py3.6.egg/comet_ml/monkey_patching.py in wrapper(*args, **kwargs)
#     244                     )
#     245
# --> 246         return_value = original(*args, **kwargs)
#     247
#     248         # Call after callbacks once we have the return value
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1294         shuffle=shuffle,
#    1295         initial_epoch=initial_epoch,
# -> 1296         steps_name='steps_per_epoch')
#    1297
#    1298   def evaluate_generator(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     219     step = 0
#     220     while step < target_steps:
# --> 221       batch_data = _get_next_batch(generator)
#     222       if batch_data is None:
#     223         if is_dataset:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_generator.py in _get_next_batch(generator)
#     361   """Retrieves the next batch of input data."""
#     362   try:
# --> 363     generator_output = next(generator)
#     364   except (StopIteration, errors.OutOfRangeError):
#     365     return None
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/utils/data_utils.py in get(self)
#     787     except Exception:  # pylint: disable=broad-except
#     788       self.stop()
# --> 789       six.reraise(*sys.exc_info())
#     790
#     791
#
# /usr/local/lib/python3.6/dist-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/utils/data_utils.py in get(self)
#     781     try:
#     782       while self.is_running():
# --> 783         inputs = self.queue.get(block=True).get()
#     784         self.queue.task_done()
#     785         if inputs is not None:
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# /usr/lib/python3.6/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     117         job, i, func, args, kwds = task
#     118         try:
# --> 119             result = (True, func(*args, **kwds))
#     120         except Exception as e:
#     121             if wrap_exception and func is not _helper_reraises_exception:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/utils/data_utils.py in get_index(uid, i)
#     569       The value at index `i`.
#     570   """
# --> 571   return _SHARED_SEQUENCES[uid][i]
#     572
#     573
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/iterator.py in __getitem__(self, idx)
#      63         index_array = self.index_array[self.batch_size * idx:
#      64                                        self.batch_size * (idx + 1)]
# ---> 65         return self._get_batches_of_transformed_samples(index_array)
#      66
#      67     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/pirates-0.1.0-py3.6.egg/pirates/models/inputs_model.py in _get_batches_of_transformed_samples(self, idxs)
#     158         # Create batch by transposing list of tuples into list of lists
#     159         example_ids, batch_X, batch_Y = [
# --> 160             list(tuples) for tuples in zip(*list_of_tuples)
#     161         ]
#     162         # Stack lists into numpy arrays
#
# ValueError: not enough values to unpack (expected 3, got 0)
